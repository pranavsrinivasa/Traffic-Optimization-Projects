# %%
from ultralytics import YOLO
import cv2
import numpy as np
from tqdm import tqdm
from ultralytics.utils.plotting import Annotator

# %%
model = YOLO('yolov8n.pt')
classes = model.names
classes
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
roi_list = []
all_rois = []

# %%
def selectROI(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        temp = [x,y]
        roi_list.append(temp)
        print(temp)

# %%
while len(all_rois)<3:
    cv2.namedWindow('ROI')
    cv2.setMouseCallback('ROI', selectROI)
    cap = cv2.VideoCapture('DJI_20240223171559_0472_D.MP4')
    roi_list = []
    while len(roi_list) < 2:
        ret,frame=cap.read()
        cv2.putText(frame,'SELECT ROI',(100,100),cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),4)
        if not ret:
            break
        cv2.imshow("ROI",frame)
        if cv2.waitKey(0)&0xFF==27:
            break
    cap.release()
    cv2.destroyAllWindows()
    all_rois.append(roi_list)
# Out:
# [938, 336]
# [849, 622]
# [794, 1031]
# [1112, 1038]
# [1087, 695]
# [1083, 353]
# [1105, 322]
# [1090, 574]
# [1105, 899]
# [1123, 1033]
# [1513, 1039]
# [1297, 569]
# [1228, 413]
# [1193, 310]
# [1227, 341]
# [1299, 509]
# [1369, 670]
# [1455, 850]
# [1545, 1014]
# [1868, 1034]
# [1731, 785]
# [1526, 535]
# [1341, 329]

# %%
all_rois
# Out:
# [[[938, 336], [849, 622], [794, 1031], [1112, 1038], [1087, 695], [1083, 353]],
#  [[1105, 322],
#   [1090, 574],
#   [1105, 899],
#   [1123, 1033],
#   [1513, 1039],
#   [1297, 569],
#   [1228, 413],
#   [1193, 310]],
#  [[1227, 341],
#   [1299, 509],
#   [1369, 670],
#   [1455, 850],
#   [1545, 1014],
#   [1868, 1034],
#   [1731, 785],
#   [1526, 535],
#   [1341, 329]]]

# %%
cv2.namedWindow('Main')
cap = cv2.VideoCapture('DJI_20240223171559_0472_D.MP4')

avg_list = []
count = 0
while True:
    ret,frame=cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    # rois = []
    for roi_list_here in all_rois:
        max = [0,0]
        min = [10000,10000]
        for i in range(len(roi_list_here)-1):
            if roi_list_here[i][0] > max[0]:
                max[0] = roi_list_here[i][0]
            if roi_list_here[i][1] > max[1]:
                max[1] = roi_list_here[i][1]
            if roi_list_here[i][0] < min[0]:
                min[0] = roi_list_here[i][0]
            if roi_list_here[i][1] < min[1]:
                min[1] = roi_list_here[i][1]
        frame_cropped = frame[min[1]:max[1],min[0]:max[0]]
        roi_corners = np.array([roi_list_here],dtype=np.int32)
        mask = np.zeros(frame.shape,dtype=np.uint8)
        mask.fill(255)
        channel_count = frame.shape[2]
        ignore_mask_color = (255,)*channel_count
        cv2.fillPoly(mask,roi_corners,0)
        mask_cropped = mask[min[1]:max[1],min[0]:max[0]]
        roi = cv2.bitwise_or(frame_cropped,mask_cropped)

        #roi = frame[roi_list_here[0][1]:roi_list_here[1][1],roi_list_here[0][0]:roi_list_here[1][0]]
        number = []
        results = model.predict(roi)
        for r in results:
            boxes = r.boxes
            counter = 0
            for box in boxes:
                counter += 1
                name = classes[box.cls.numpy()[0]]
                conf = str(round(box.conf.numpy()[0],2))
                text = name+conf
                bbox = box.xyxy[0].numpy()
                cv2.rectangle(frame,(int(bbox[0])+min[0],int(bbox[1])+min[1]),(int(bbox[2])+min[0],int(bbox[3])+min[1]),(0,255,0),2)
                cv2.putText(frame,text,(int(bbox[0])+min[0],int(bbox[1])+min[1]-5),cv2.FONT_HERSHEY_SIMPLEX, 0.4,(0,0,255),2)
            number.append(counter)
        avg = sum(number)/len(number)
        stats = str(round(avg,2))
        cv2.putText(frame,stats,(min[0],min[1]),cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,0),4)
        cv2.polylines(frame,roi_corners,True,(255,0,0),2)
    cv2.putText(frame,'The average number of vehicles in the Regions of Interest',(100,100),cv2.FONT_HERSHEY_SIMPLEX, 1,(0,0,255),4)
    cv2.imshow('Main',frame)
    if cv2.waitKey(1)&0xFF==27:
         break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x320 3 persons, 21 cars, 3 buss, 89.0ms
# Speed: 1.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 5 persons, 16 cars, 3 buss, 2 trucks, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 7 persons, 10 cars, 2 buss, 3 trucks, 139.0ms
# Speed: 4.0ms preprocess, 139.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 2 persons, 21 cars, 4 buss, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 5 persons, 16 cars, 2 buss, 3 trucks, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 6 persons, 9 cars, 3 buss, 2 trucks, 137.0ms
# Speed: 4.0ms preprocess, 137.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 21 cars, 4 buss, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 4 persons, 17 cars, 4 buss, 3 trucks, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 4 persons, 9 cars, 3 buss, 2 trucks, 137.0ms
# Speed: 3.0ms preprocess, 137.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 21 cars, 4 buss, 1 cell phone, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 6 persons, 15 cars, 2 buss, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 5 persons, 9 cars, 3 buss, 4 trucks, 140.0ms
# Speed: 4.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 21 cars, 4 buss, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 7 persons, 14 cars, 5 buss, 1 truck, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 5 persons, 10 cars, 4 buss, 3 trucks, 121.0ms
# Speed: 6.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 20 cars, 4 buss, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 3 persons, 12 cars, 3 buss, 2 trucks, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 7 persons, 9 cars, 2 buss, 5 trucks, 136.0ms
# Speed: 4.0ms preprocess, 136.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 19 cars, 4 buss, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 3 persons, 14 cars, 6 buss, 3 trucks, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 7 persons, 10 cars, 2 buss, 2 trucks, 135.0ms
# Speed: 3.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 2 persons, 19 cars, 4 buss, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 4 persons, 12 cars, 7 buss, 2 trucks, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 5 persons, 10 cars, 4 buss, 2 trucks, 122.0ms
# Speed: 4.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 19 cars, 5 buss, 1 cell phone, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 5 persons, 16 cars, 7 buss, 2 trucks, 93.0ms
# Speed: 1.0ms preprocess, 93.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 7 persons, 8 cars, 3 buss, 2 trucks, 136.0ms
# Speed: 4.0ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 21 cars, 4 buss, 85.0ms
# Speed: 3.0ms preprocess, 85.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 6 persons, 15 cars, 5 buss, 2 trucks, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 7 persons, 10 cars, 2 buss, 3 trucks, 130.0ms
# Speed: 4.0ms preprocess, 130.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 2 persons, 19 cars, 4 buss, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 3 persons, 17 cars, 5 buss, 1 truck, 1 traffic light, 95.0ms
# Speed: 1.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 5 persons, 11 cars, 2 buss, 1 truck, 130.0ms
# Speed: 4.0ms preprocess, 130.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 2 persons, 20 cars, 5 buss, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 3 persons,
0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 26 cars, 5 buss, 131.0ms
# Speed: 1.0ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 4 persons, 23 cars, 1 bus, 136.0ms
# Speed: 4.0ms preprocess, 136.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 16 cars, 6 buss, 95.0ms
# Speed: 7.0ms preprocess, 95.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 27 cars, 6 buss, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 2 persons, 23 cars, 1 bus, 139.0ms
# Speed: 4.0ms preprocess, 139.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 3 persons, 17 cars, 4 buss, 1 truck, 111.0ms
# Speed: 3.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 29 cars, 7 buss, 128.0ms
# Speed: 2.0ms preprocess, 128.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 2 persons, 24 cars, 1 bus, 1 truck, 137.0ms
# Speed: 4.0ms preprocess, 137.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 5 persons, 19 cars, 5 buss, 1 truck, 96.0ms
# Speed: 3.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x384 28 cars, 7 buss, 1 traffic light, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 3 persons, 24 cars, 1 bus, 135.0ms
# Speed: 4.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 38
#      36 #roi = frame[roi_list_here[0][1]:roi_list_here[1][1],roi_list_here[0][0]:roi_list_here[1][0]]
#      37 number = []
# ---> 38 results = model.predict(roi)
#      39 for r in results:
#      40     boxes = r.boxes
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:452, in Model.predict(self, source, stream, predictor, **kwargs)
#     450 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     451     self.predictor.set_prompts(prompts)
# --> 452 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\autobackend.py:447, in AutoBackend.forward(self, im, augment, visualize, embed)
#     445 # PyTorch
#     446 if self.pt or self.nn_module:
# --> 447     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     449 # TorchScript
#     450 elif self.jit:
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\modules\block.py:230, in C2f.forward(self, x)
#     228 """Forward pass through C2f layer."""
#     229 y = list(self.cv1(x).chunk(2, 1))
# --> 230 y.extend(m(y[-1]) for m in self.m)
#     231 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\modules\block.py:230, in <genexpr>(.0)
#     228 """Forward pass through C2f layer."""
#     229 y = list(self.cv1(x).chunk(2, 1))
# --> 230 y.extend(m(y[-1]) for m in self.m)
#     231 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\modules\block.py:340, in Bottleneck.forward(self, x)
#     338 def forward(self, x):
#     339     """'forward()' applies the YOLO FPN to input data."""
# --> 340     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\activation.py:393, in SiLU.forward(self, input)
#     392 def forward(self, input: Tensor) -> Tensor:
# --> 393     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\Pranav\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:2074, in silu(input, inplace)
#    2072     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2073 if inplace:
# -> 2074     return torch._C._nn.silu_(input)
#    2075 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
